# %%
"""
print() — Python-da məlumatı ekrana çıxarmaq üçün istifadə olunan ən əsas funksiyadır.
İstifadəçiyə mətn, rəqəm, dəyişən, hesablama nəticəsi və ya obyekt haqqında məlumat göstərmək üçün istifadə olunur.

"""
print("Salam Data")
# Out:
# Salam Data

# %%
print(5)
print(10 + 3)
# Out:
# 5
# 13

# %%
#Bir neçə elementi yan-yana yazdırmaq
#Varsayılan olaraq Python elementləri boşluqla ayırır.

print("A", "B", "C")
# Out:
# A B C

# %%
#sep parametri (ayırıcı)
#Elementlərin arasına hansı işarənin qoyulacağını müəyyən edir.

print("A", "B", "C", sep="-")
# Out:
# A-B-C

# %%
print("2025", "03", "14", sep="/")
# Out:
# 2025/03/14

# %%
"""
\n simvolu – print() funksiyası bir sətir içində bu simvolu görəndə, mətnin çapına növbəti sətrdən davam edir. 
 Yəni, \n yeni sətir keçidini təmin edir.
"""

print("Birinci sətir\nİkinci sətir")
# Out:
# Birinci sətir
# İkinci sətir

# %%
"""
\t simvolu – print() funksiyası string daxilində bu simvola rast gəldikdə, çap zamanı bir tab qədər boşluq buraxaraq davam edir. 
Yəni, mətnlər arasında daha geniş ara yaratmaq üçün istifadə olunur.
"""

print("Ad:\tƏli")
print("Yaş:\t20")
# Out:
# Ad:	Əli
# Yaş:	20

# %%
print("a\t\t\t\t\tb")
# Out:
# a					b

# %%
#Ulduzlu (*) parametrlər — stringi simvollarına ayırmaq

print(*"Python")
# Out:
# P y t h o n

# %%
print(*"Python",sep = "\n")
# Out:
# P
# y
# t
# h
# o
# n

# %%
""""
end parametri (sətirin sonu)
Hər print() sonda avtomatik \n (yeni sətir) əlavə edir.
Bunu dəyişmək üçün end istifadə olunur.
"""

print("Vahid")
print("Cavid")
# Out:
# Vahid
# Cavid

# %%
print("Salam", end=" ")
print("Data")
# Out:
# Salam Data

# %%
print("Start", end=" --> ")
print("Finish")
# Out:
# Start --> Finish

# %%
#Python’da şərhlər (comments)

# tək sətir şərh yazmaq üçün istifadə olunur """ isə bir neçə sətirdən ibarət kod yazmaq üçün istifadə olunur

# %%
#Python’da dəyişənlər (variables)

ad = "Əli"
yas = 20
print(ad)
print(yas)
# Out:
# Əli
# 20

# %%
a=4
b=5
print(a+b,a-b,a*b,a/b,sep="\n")
# Out:
# 9
# -1
# 20
# 0.8

# %%
#Dəyişən adı hərf və ya alt xətt (_) ilə başlamalıdır.
_a=2 
c=1

print(_a+c)
# Out:
# 3

# %%
-v=2
d=1

print(-v+d)
# Out:
#   Cell In[20], line 1
#     -v=2
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
1v=2
r=4

print(1v+r)
# Out:
#   Cell In[25], line 1
#     1v=2
#     ^
# SyntaxError: invalid decimal literal

# %%
#Python-da Əsas Riyazi (Matematik) Operatorlar

#toplama +

a = 14
b = 15
a + b
# Out:
# 29

# %%
#çıxma -

a = 43
b = 21 
a - b
# Out:
# 22

# %%
#vurma   *

a = 4
b = 5
a *b
# Out:
# 20

# %%
# bölmə /

a = 4
b = 2
print(a/b)

# qalıqsız bölmə //

a = 3
b = 2
a//b
# Out:
# 2.0
# 1

# %%
# Qalıq tapma ( % )

a = 17
b = 5
print(a % b)
# Out:
# 2

# %%
# Üstə qaldırma / qüvvətə yüksəltmə ( ** )
# Bir ədədi başqa bir ədədin qüvvətinə yüksəldir.

a = 2
b = 5
print(a ** b)
# Out:
# 32

# %%
# Mənfi işarə ( unary minus )
# Bir ədədin işarəsini dəyişir

a = 10
print(-a)
# Out:
# -10

# %%
#Formatlama

#Burada 3 ədəd fiqurlu mötərizə ({}) var və onların yerinə format funksiyasının içindəki dəyərlər ardıcıllıqla yerləşdirilir.

"{} {} {}".format(3.1423, 5.324, 7.324324)
# Out:
# '3.1423 5.324 7.324324'

# %%
a = 3
b = 4
print("{} + {} ədədinin cəmi {}-dır".format(a, b, a+b))
# Out:
# 3 + 4 ədədinin cəmi 7-dır

# %%
# Format spec (tam adı: format specification) — format() və f-string içində {} mötərizəsinin içində yazılan xüsusi qaydadır.
# Bu qayda Python-a deyir ki, həmin dəyəri necə formatlamalıdır:

"{:.2f}".format(3.14159)

# Burada :.2f format_spec-dir və Python-a deyir:
# f → float formatı
# .2 → vergüldən sonra 2 rəqəm göstər
# Out:
# '3.14'

# %%
"{:.3f}".format(3.14159)
# Out:
# '3.142'

# %%
#Fiqurlu mötərizələrin içindəki rəqəmlər format funksiyasının içində hansı sıradakı dəyərin gələcəyini göstərir.

"{1} {0} {2}".format(43, "Murat", 54)
# Out:
# 'Murat 43 54'

# %%
# Faiz çevirmək 

"{:.1%}".format(0.257)
# Out:
# '25.7%'

# %%
#İstifadəçidən məlumat almaq – input() funksiyası 

input()
# Out:
# '3'

# %%
input("Reqem daxil edin:")
# Out:
# '6'

# %%
#İstifadəçinin daxil etdiyi dəyər input() funksiyasından bizə string (mətin) olaraq qaytarılır.

a = input("reqem daxil edin:")
print(type(a))
# Out:
# <class 'str'>

# %%
# aşağıdakı kodda əgər istifadəçi 5 daxil etsə, 5 * 3 = 15 olmasını gözləyirik.Lakin nəticə belə çıxır:
#Zəhmət olmasa bir ədəd daxil edin:5    555

a = input("Zəhmət olmasa bir ədəd daxil edin:")
print(a * 3)
# Out:
# 555

# %%
#Düzgün İşləmə

a = int(input("Zəhmət olmasa bir ədəd daxil edin:"))  # Məlumat tipinin çevrilməsi
print(a * 3)
# Out:
# 15

# %%
# float üçün nümunə 

a = input("Zəhmət olmasa bir ədəd daxil edin:")
print(a * 3)  # Daxil edilən dəyər 5.4 olsa, nəticənin 16.2 olmasını gözləyərik. Amma nəticə 5.45.45.4 kimi çıxır.
# Out:
# 5.45.45.4

# %%
# duzgun versiya 

a = float(input("Zəhmət olmasa bir ədəd daxil edin:"))
print(a * 3)  # Daxil edilən dəyər 5.4 olsa, nəticənin 16.2 olmasını gözləyirik.
# Out:
# 16.200000000000003

# %%
# Gəlin bir nümunə proqram yazaq. 

a = int(input("Birinci ədəd:"))
b = int(input("İkinci ədəd:"))
c = int(input("Üçüncü ədəd:"))

print("Toplamları:", a + c + b)
# Out:
# Toplamları: 12

# %%
# tam ədəd (int) ondalığlı ədəd (float) ilə çevrilməlidir hər ikisi ədəddir yanaşması burada xəta almağa gətirib çıxaracaq 
# məsələn aşağıda int ilə tam ədədə çevirirəm ama ondalığlı ədəd daxil etsəm ekranda xəta alacam çünmki belə olan halda float
# ilə çevirməli idim nümunə olaraq aşğıdakı koda bir 3.14 ədədini daxil edirəm

a = int(input("bir eded daxil edin:"))
print(a*3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 5
#       1 # tam ədəd (int) ondalığlı ədəd (float) ilə çevrilməlidir hər ikisi ədəddir yanaşması burada xəta almağa gətirib çıxaracaq
#       2 # məsələn aşağıda int ilə tam ədədə çevirirəm ama ondalığlı ədəd daxil etsəm ekranda xəta alacam çünmki belə olan halda float
#       3 # ilə çevirməli idim nümunə olaraq aşğıdakı koda bir 3.14 ədədini daxil edirəm
# ----> 5 a = int(input("bir eded daxil edin:"))
#       6 print(a*3)
#
# ValueError: invalid literal for int() with base 10: '3.4'

# %%
a = 5
a
# Out:
# 5
