# %%
def k(a, b, c):
    return b-(a*c)
print("Nəticə:", k(8, 20, 4))
# Out:
# Nəticə: -12

# %%
k(8,7,5)
# Out:
# -33

# %%
def m():
    x, y, z = "Orange", "OO", "CH"
    print(x)
    print(y)
    print(z)

# %%
m()
# Out:
# Orange
# OO
# CH

# %%
def n(a,b):
    print(a*b)
n(2,6)
# Out:
# 12

# %%
def test():
    print(10)

test()
# Out:
# 10

# %%
def test():
    return 10

x = test()
print(x)
# Out:
# 10

# %%
test()
# Out:
# 10

# %%
test()
# Out:
# 10

# %%
def a(a,b):
    return a+b
a(2,6)
# Out:
# 8

# %%
a(3,4)
# Out:
# 7

# %%
def ya(a):
    print (*a, sep="\n")
ya("World")
# Out:
# W
# o
# r
# l
# d

# %%
def ya(a):
    print (*a)
ya("World")
# Out:
# W o r l d

# %%
def r(a,b,c):
    print(f"{a+b} < {c}")
r(2,6,5)
# Out:
# 8 < 5

# %%
def hesabla_return(a, b):
    print ((a*b, a+b, b-a))
hesabla_return(5, 6)
# Out:
# (30, 11, 1)

# %%
def hesabla_return(a, b, c):
    return (a*b, b+c)
hesabla_return(5, "6", "3")
# Out:
# ('66666', '63')

# %%
def u ():
    print("{:.2%}".format(0.257))
u()
# Out:
# 25.70%

# %%
def u ():
    return "{:.2f}".format(0.257)
u()
# Out:
# '0.26'

# %%
def salam(ad):
    return "Data analitika dərsinə xoş gəlmisiniz: {}".format(ad)
print(salam("Vaqif"))
# Out:
# Data analitika dərsinə xoş gəlmisiniz: Vaqif

# %%
def salam(ad):
    print("Data analitika dərsinə xoş gəlmisiniz:", ad)
salam("Vaqif")
# Out:
# Data analitika dərsinə xoş gəlmisiniz: Vaqif

# %%
def salam():
    print("Data analitika dərsinə xoş gəlmisiniz:", "Vaqif")
salam()
# Out:
# Data analitika dərsinə xoş gəlmisiniz: Vaqif

# %%
def n(a,b,c):
    return a+b*c
n(2,3,4)
# Out:
# 14

# %%
ad = input("Ad daxil edin: ")                        
bal = float(input("Bal daxil edin: "))          

def r (ad, bal):
    print(f"Tələbə: {ad}, Balı: {bal:.2f}") 
r(ad, bal)
# Out:
# Tələbə: Nicat, Balı: 75.00

# %%
try:
    pul = float(input("ne qeder pulunuz var"))
    qiymet = float(input("dondurma neciyedir?"))

    if pul<=0 or qiymet<=0:
        print("pul ve ya qiymet 0-dan boyuk olmalidir")
    
    say = round(pul/qiymet)
    qaliq = pul - (qiymet*say)

    print("sizin {} manat pulunuza {} ədəd dondurma düşür".format(pul,qiymet))
    print("size qaytarilacaq olan pul {} manatdir ".format(qaliq))
except ValueError:
    print("qiymet ve ya pul reqem olmalidir")
# Out:
# sizin 18.0 manat pulunuza 17.0 ədəd dondurma düşür
# size qaytarilacaq olan pul 1.0 manatdir
